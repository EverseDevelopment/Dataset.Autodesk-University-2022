# %%
import requests
from bs4 import BeautifulSoup

# %%
url ="https://www.autodesk.com/autodesk-university/au-online"
headers = {"User-agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.80 Safari/537.36"}
r = requests.get(url, headers= headers)
  
soup = BeautifulSoup(r.content, 'html.parser') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="og: https://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-69ddd2f3aaa8db54fa2",applicationID:"641597882"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n,r){return function(){return s.recordSupportability("API/"+e+"/called"),o(t+e,[u.now()].concat(c(arguments)),n?null:this,r),n?void 0:this}}var o=t("handle"),a=t(9),c=t(10),f=t("ee").get("tracer"),u=t("loader"),s=t(4),d=NREUM;"undefined"==typeof window.newrelic&&(newrelic=d);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",v=l+"ixn-";a(p,function(t,e){d[e]=i(l,e,!0,"api")}),d.addPageAction=i(l,"addPageAction",!0),d.setCurrentRouteName=i(l,"routeName",!0),e.exports=newrelic,d.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(v+"tracer",[u.now(),t,n],r),function(){if(f.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw f.emit("fn-err",[arguments,this,t],n),t}finally{f.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(v,e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),s.recordSupportability("API/noticeError/called"),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){var r=!1;try{var i=Object.defineProperty({},"passive",{get:function(){r=!0}});window.addEventListener("testPassive",null,i),window.removeEventListener("testPassive",null,i)}catch(o){}e.exports=function(t){return r?{passive:!0,capture:!!t}:!!t}},{}],4:[function(t,e,n){function r(t,e){var n=[a,t,{name:t},e];return o("storeMetric",n,null,"api"),n}function i(t,e){var n=[c,t,{name:t},e];return o("storeEventMetrics",n,null,"api"),n}var o=t("handle"),a="sm",c="cm";e.exports={constants:{SUPPORTABILITY_METRIC:a,CUSTOM_METRIC:c},recordSupportability:r,recordCustom:i}},{}],5:[function(t,e,n){function r(){return c.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,c=t(11);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],6:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?l("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&l("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();if(n.length>0){var r=n[n.length-1];if(u&&u<r.startTime)return;var i=[r],o=a({});o&&i.push(o),l("lcp",i)}}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||l("cls",[t])})}function a(t){var e=navigator.connection||navigator.mozConnection||navigator.webkitConnection;if(e)return e.type&&(t["net-type"]=e.type),e.effectiveType&&(t["net-etype"]=e.effectiveType),e.rtt&&(t["net-rtt"]=e.rtt),e.downlink&&(t["net-dlink"]=e.downlink),t}function c(t){if(t instanceof y&&!w){var e=Math.round(t.timeStamp),n={type:t.type};a(n),e<=v.now()?n.fid=v.now()-e:e>v.offset&&e<=Date.now()?(e-=v.offset,n.fid=v.now()-e):e=v.now(),w=!0,l("timing",["fi",e,n])}}function f(t){"hidden"===t&&(u=v.now(),l("pageHide",[u]))}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var u,s,d,p,l=t("handle"),v=t("loader"),m=t(8),g=t(3),y=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof ...
#   </script>
#   <noscript>
#    <style>
#     form.antibot * :not(.antibot-message) { display: none !important; }
#    </style>
#   </noscript>
#   <style>
#    /* @see https://github.com/aFarkas/lazysizes#broken-image-symbol */.js img.lazyload:not([src]) { visibility: hidden; }/* @see https://github.com/aFarkas/lazysizes#automatically-setting-the-sizes-attribute */.js img.lazyloaded[data-sizes=auto] { display: block; width: 100%; }
#   </style>
#   <link href="https://www.autodesk.com/autodesk-university/au-online" rel="canonical"/>
#   <link href="https://www.autodesk.com/autodesk-university/au-online" rel="shortlink"/>
#   <meta content="Autodesk University" property="og:site_name"/>
#   <meta content="https://www.autodesk.com/autodesk-university/au-online" property="og:url"/>
#   <meta content="Free Online Classes and Tutorials" property="og:title"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Free Online Classes and Tutorials" name="twitter:title"/>
#   <meta content="https://www.autodesk.com/autodesk-university/au-online" name="twitter:url"/>
#   <meta content="Drupal 8 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="/autodesk-university/themes/custom/forgecms_subtheme_auonline/favicon/autodesk-symbol-32x32.svg" rel="shortcut icon" type="image/svg+xml"/>
#   <script>
#    window.a2a_config=window.a2a_config||{};a2a_config.callbacks=[];a2a_config.overlays=[];a2a_config.templates={};a2a_config.track_links = 'bitly';
# a2a_config.track_links_key = 'autodeskinc|R_b8b61f7c745d42b3a997bc0b8f0354e3';
#   </script>
#   <title>
#    Free Online Classes and Tutorials | Autodesk University
#   </title>
#   <link href="/autodesk-university/sites/default/files/css/css__PEGs90Azq3kz59dUSlGL9kINh7HZStuCaZedy6U1Gg.css" media="all" rel="stylesheet"/>
#   <link href="/autodesk-university/themes/custom/forgecms_subtheme_auonline/assets/css/forgecms_subtheme_auonline.css?rjjzhg" media="all" rel="stylesheet"/>
#   <!--[if lte IE 8]>
# <script src="/autodesk-university/sites/default/files/js/js_QCj0rpJxZHyO8VmaZPQ76T64Gikmny6x2qC6jLl2ibw.js"></script>
# <![endif]-->
#   <script src="/autodesk-university/core/assets/vendor/modernizr/modernizr.min.js?v=3.3.1">
#   </script>
#   <script src="//help.autodesk.com/videos/plugin/v2/AKPVideoPlayerHelper.js">
#   </script>
#   <link href="/autodesk-university/themes/custom/forgecms_subtheme_auonline/favicon/autodesk-symbol-32x32.svg" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/autodesk-university/themes/custom/forgecms_subtheme_auonline/favicon/autodesk-symbol-32x32.svg" rel="icon" sizes="32x32" type="image/svg+xml"/>
#   <link href="/autodesk-university/themes/custom/forgecms_subtheme_auonline/favicon/autodesk-symbol-32x32.svg" rel="icon" sizes="16x16" type="image/svg+xml"/>
#   <link href="/autodesk-university/themes/custom/forgecms_subtheme_auonline/favicon/site.webmanifest" rel="manifest"/>
#   <link color="#5bbad5" href="/autodesk-university/themes/custom/forgecms_subtheme_auonline/favicon/autodesk-symbol-32x32.svg" rel="mask-icon"/>
#   <meta content="#b91d47" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <script>
#    (window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);
#   </script>
#   <script>
#    !function(a){var e="https://s.go-mpulse.net/boomerang/",t="addEventListener";if("False"=="True")a.BOOMR_config=a.BOOMR_config||{},a.BOOMR_config.PageParams=a.BOOMR_config.PageParams||{},a.BOOMR_config.PageParams.pci=!0,e="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="7EBBQ-LTQQA-LAAVF-GNKJF-H85LA",function(){function n(e){a.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!a.BOOMR||!a.BOOMR.version&&!a.BOOMR.snippetExecuted){a.BOOMR=a.BOOMR||{},a.BOOMR.snippetExecuted=!0;var i,_,o,r=document.createElement("iframe");if(a[t])a[t]("load",n,!1);else if(a.attachEvent)a.attachEvent("onload",n);r.src="javascript:void(0)",r.title="",r.role="presentation",(r.frameElement||r).style.cssText="width:0;height:0;border:0;display:none;",o=document.getElementsByTagName("script")[0],o.parentNode.insertBefore(r,o);try{_=r.contentWindow.document}catch(O){i=document.domain,r.src="javascript:var d=document.open();d.domain='"+i+"';void(0);",_=r.contentWindow.document}_.open()._l=function(){var a=this.createElement("script");if(i)this.domain=i;a.id="boomr-if-as",a.src=e+"7EBBQ-LTQQA-LAAVF-GNKJF-H85LA",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(a)},_.write("<bo"+'dy onload="document._l();">'),_.close()}}(),"".length>0)if(a&&"performance"in a&&a.performance&&"function"==typeof a.performance.setResourceTimingBufferSize)a.performance.setResourceTimingBufferSize();!function(){if(BOOMR=a.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var e=""=="true"?1:0,t="",n="wmapbiqx326csy2fzjpq-f-c07c44519-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,_={"ak.v":"32","ak.cp":"544838","ak.ai":parseInt("354010",10),"ak.ol":"0","ak.cr":41,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"16098547","ak.r":40468,"ak.a2":e,"ak.m":"x","ak.n":"essl","ak.bpcip":"179.0.240.0","ak.cport":23507,"ak.gh":"23.196.15.125","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1665518175","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"243","ak.dpoabenc":"","ak.tf":i};if(""!==t)_["ak.ruds"]=t;var o={i:!1,av:function(e){var t="http.initiator";if(e&&(!e[t]||"spa_hard"===e[t]))_["ak.feo"]=void 0!==a.aFeoApplied?1:0,BOOMR.addVar(_)},rv:function(){var a=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(a)}};BOOMR.plugins.AK={akVars:_,akDNSPreFetchDomain:n,init:function(){if(!o.i){var a=BOOMR.subscribe;a("before_beacon",o.av,null,null),a("onbeacon",o.rv,null,null),o.i=!0}return this},is_complete:function(){return!0}}}}()}(window);
#   </script>
#  </head>
#  <body class="lang-en">
#   <a class="visually-hidden focusable" href="#main-content">
#    Skip to main content
#   </a>
#   <div class="page-container" data-wat-link-section="page-content">
#    <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#     <header class="global-header" id="global-header">
#      <div class="container global-header__top-bar container--dynamic">
#       <div class="grid">
#        <a class="global-header__logo grid__item intermediate--one-third" data-wat-linkname="Autodesk logo" data-wat-loc="Header" href="https://www.autodesk.com/">
#         <div id="block-sitebranding">
#          <img alt="Autodesk University logo" class="site-logo" src="https://damassets.autodesk.net/content/dam/autodesk/logos/autodesk-logo-wht.svg"/>
#         </div>
#        </a>
#        <div class="global-header__user grid__item">
#         <a class="global-header__language-switcher" data-toggle=".region-language-dropdown" href="javascript:;">
#          <div class="global-header__globe-icon">
#           <svg viewbox="0 0 24 24">
#            <path d="M22 12H2m20 0c0-1.821-.487-3.53-1.338-5M22 12c0 1.821-.487 3.53-1.338 5M12 22V2m0 20c11.5-10 0-20 0-20m0 20C.5 12 12 2 12 2m0 20a9.996 9.996 0 0 0 8.662-5M12 22a9.996 9.996 0 0 1-8.662-5M2 12c0-1.821.487-3.53 1.338-5M2 12c0 1.821.487 3.53 1.338 5M12 2a9.996 9.996 0 0 1 8.662 5M12 2a9.996 9.996 0 0 0-8.662 5m17.324 0H3.338m17.324 10H3.338" stroke="#fff" stroke-linejoin="round" stroke-width="1.3">
#            </path>
#           </svg>
#          </div>
#         </a>
#         <div class="global-header__user-basics global-header__user-basics--dhcl-user-bar">
#          <div class="aufeComponent usermenu" data-component="UserMenu" data-linkprefix="/autodesk-university">
#          </div>
#         </div>
#         <div class="region region-user-dropdown dropdown-animate" data-listen="">
#          <nav aria-labelledby="block-useraccountmenu-menu" class="au-menu-column--bordered au-menu-column" id="block-useraccountmenu" role="navigation">
#           <h2 class="au-menu-column__title" id="block-useraccountmenu-menu">
#            Autodesk University
#           </h2>
#           <ul class="menu" data-wat-link-section="Menu: account">
#            <li class="menu__item">
#             <a class="menu__link au-link" href="/autodesk-university/au-online/profile" target="">
#              My Public Profile
#             </a>
#            </li>
#            <li class="menu__item">
#             <a class="menu__link au-link" data-access="1" data-registered="1" data-speaker="1" href="https://autodeskuniversity.smarteventscloud.com/portal/myAccount.ww" style="display:none;" target="">
#              My Registration
#             </a>
#            </li>
#            <li class="menu__item">
#             <a class="js-role-access menu__link au-link" data-speaker="1" data-speaker-nonregistered="1" href="https://autodeskuniversity.smarteventscloud.com/content" style="display:none;" target="_blank">
#              Speaker Resources
#             </a>
#            </li>
#            <li class="menu__item menu-item--active-trail">
#             <a class="menu__link au-link" data-access="1" data-registered="1" href="/autodesk-university/au-online?filter_attended=1" style="display:none;" target="" title="My attended sessions">
#              My attended sessions
#             </a>
#            </li>
#            <li class="menu__item">
#             <a class="menu__link au-link" data-access="1" data-registered="1" data-signedin="1" href="/autodesk-university/au-online?filter_bookmarks=1" style="display:none;" target="" title="My bookmarks">
#              My bookmarks
#             </a>
#            </li>
#           </ul>
#          </nav>
#          <nav aria-labelledby="block-autodeskaccount-menu" class="au-menu-column--bordered au-menu-column" id="block-autodeskaccount" role="navigation">
#           <h2 class="au-menu-column__title" id="block-autodeskaccount-menu">
#            AUTODESK ACCOUNT
#           </h2>
#           <ul class="menu" data-wat-link-section="Menu: autodesk-account">
#            <li class="menu__item">
#             <a class="menu__link au-link" href="https://manage.autodesk.com/cep/" target="">
#              Manage Products &amp; Downloads
#             </a>
#            </li>
#            <li class="menu__item">
#             <a class="menu__link au-link" href="https://accounts.autodesk.com/Profile/Security" target="">
#              Security Settings
#             </a>
#            </li>
#           </ul>
#          </nav>
#         </div>
#         <div class="region region-language-dropdown dropdown-animate" data-listen="">
#          <div class="language-switcher-language-url" id="block-languageswitcher" role="navigation">
#           <ul class="links">
#            <li class="en language-switcher-item is-active" data-drupal-link-system-path="au-online" hreflang="en">
#             <a class="language-link is-active" data-drupal-link-system-path="au-online" href="/autodesk-university/au-online" hreflang="en">
#              English
#             </a>
#            </li>
#            <li class="de language-switcher-item" data-drupal-link-system-path="au-online" hreflang="de">
#             <a class="language-link" data-drupal-link-system-path="au-online" href="/autodesk-university/de/au-online" hreflang="de">
#              Deutsch
#             </a>
#            </li>
#            <li class="ja language-switcher-item" data-drupal-link-system-path="au-online" hreflang="ja">
#             <a class="language-link" data-drupal-link-system-path="au-online" href="/autodesk-university/ja/au-online" hreflang="ja">
#              日本語
#             </a>
#            </li>
#            <li class="fr language-switcher-item" data-drupal-link-system-path="au-online" hreflang="fr">
#             <a class="language-link" data-drupal-link-system-path="au-online" href="/autodesk-university/fr/au-online" hreflang="fr">
#              Français
#             </a>
#            </li>
#            <li class="es language-switcher-item" data-drupal-link-system-path="au-online" hreflang="es">
#             <a class="language-link" data-drupal-link-system-path="au-online" href="/autodesk-university/es/au-online" hreflang="es">
#              Español
#             </a>
#            </li>
#            <li class="ru language-switcher-item" data-drupal-link-system-path="au-online" hreflang="ru">
#             <a class="language-link" data-drupal-link-system-path="au-online" href="/autodesk-university/ru/au-online" hreflang="ru">
#              русский
#             </a>
#            </li>
#            <li class="zh-hans language-switcher-item" data-drupal-link-system-path="au-online" hreflang="zh-hans">
#             <a class="language-link" data-drupal-link-system-path="au-online" href="/autodesk-university/zh-hans/au-online" hreflang="zh-hans">
#              中文
#             </a>
#            </li>
#            <li class="ko language-switcher-item" data-drupal-link-system-path="au-online" hreflang="ko">
#             <a class="language-link" data-drupal-link-system-path="au-online" href="/autodesk-university/ko/au-online" hreflang="ko">
#              한국어
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="global-header__navigation-wrapper">
#       <div class="container container--dynamic">
#        <div class="grid">
#         <div class="global-header__site-slogan medium--one-third small--two-thirds grid__item">
#          <a class="logo-university" data-wat-linkname="Autodesk University logo" data-wat-loc="Header" href="/autodesk-university/">
#           <span>
#            AUTODESK UNIVERSITY
#           </span>
#          </a>
#         </div>
#         <div class="global-header__navbar grid__item">
#          <div class="global-header__search">
#           <a class="global-header__search-expander js-global-header__search-expander" href="#">
#            <!-- Generated by IcoMoon.io -->
#            <svg height="28" version="1.1" viewbox="0 0 26 28" width="26" xmlns="http://www.w3.org/2000/svg">
#             <title>
#              search
#             </title>
#             <path d="M18 13c0-3.859-3.141-7-7-7s-7 3.141-7 7 3.141 7 7 7 7-3.141 7-7zM26 26c0 1.094-0.906 2-2 2-0.531 0-1.047-0.219-1.406-0.594l-5.359-5.344c-1.828 1.266-4.016 1.937-6.234 1.937-6.078 0-11-4.922-11-11s4.922-11 11-11 11 4.922 11 11c0 2.219-0.672 4.406-1.937 6.234l5.359 5.359c0.359 0.359 0.578 0.875 0.578 1.406z">
#             </path>
#            </svg>
#           </a>
#           <div class="global-header__info">
#            <div class="region region-search">
#             <div class="search-form search-form--library" data-drupal-selector="search-form" id="block-librarysearchblock">
#              <a class="global-header__filter-expander" data-toggle="#library-filters" href="javascript:;">
#               <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                <title>
#                 filter-24
#                </title>
#                <g id="assets">
#                 <path d="M13,20H11a1.08,1.08,0,0,1-1-1V14.75L3.69,9.86A2.13,2.13,0,0,1,3,8.5V7A1,1,0,0,1,4,6H20a1.12,1.12,0,0,1,.49.12A1,1,0,0,1,21,7V8.5a1.78,1.78,0,0,1-.71,1.39L14,14.75V19A1.08,1.08,0,0,1,13,20ZM4,7V8.5a1.24,1.24,0,0,0,.35.61L11,14.25V19h2V14.25l6.69-5.17A.79.79,0,0,0,20,8.5V7Z">
#                 </path>
#                </g>
#               </svg>
#              </a>
#              <form accept-charset="UTF-8" action="/autodesk-university/au-online" id="search-form" method="get">
#               <div class="js-form-item form-item js-form-type-textfield form-item-query js-form-item-query form-no-label" data-orient="column">
#                <input aria-required="true" autocomplete="off" class="form-text required" data-drupal-selector="edit-query" data-size="default" data-style="default" id="edit-query--2" maxlength="128" name="query" placeholder="Search AU Library" required="required" size="60" type="text" value=""/>
#               </div>
#               <div class="form-actions js-form-wrapper form-wrapper" data-drupal-selector="edit-actions" id="edit-actions">
#               </div>
#              </form>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="region region-navigation">
#           <div class="block block-system block-system-menu-blockmega-navigation" id="block-meganavigation">
#            <div class="menu--toggle js-menu-toggle menu--header--toggle">
#             <div class="cio-ui-icon" data-icon="icon-hamburger" data-type="owf">
#             </div>
#             <a class="js-nav-close close-navigation is-hidden" href="#">
#              <!-- Generated by IcoMoon.io -->
#              <svg height="32" version="1.1" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#               <title>
#                close
#               </title>
#               <path d="M30 24.398l-8.406-8.398 8.406-8.398-5.602-5.602-8.398 8.402-8.402-8.402-5.598 5.602 8.398 8.398-8.398 8.398 5.598 5.602 8.402-8.402 8.398 8.402z">
#               </path>
#              </svg>
#              Close
#             </a>
#            </div>
#            <div class="navigation-wrapper">
#             <ul class="menu js-menu menu--inline" data-wat-link-section="Menu: mega-navigation">
#              <li class="menu__item js-menu-item menu--inline__item menu--header__item menu-item--expanded no-title">
#               <span class="no-title menu__link menu--header__link" data-listen="" data-toggle="">
#                Attend
#                <div class="cio-ui-icon menu--header__link__icon" data-icon="icon-dropdown-arrow" data-type="">
#                </div>
#               </span>
#               <ul class="menu js-menu menu--inline menu--header--level-1 dropdown-animate" data-listen="" data-wat-link-section="Menu: mega-navigation">
#                <li class="menu__item js-menu-item menu--header--level-1__item">
#                 Agenda
#                </li>
#                <li class="menu__item js-menu-item menu--header--level-1__item">
#                 Executive Pass
#                </li>
#                <li class="menu__item js-menu-item menu--header--level-1__item">
#                 Expo
#                </li>
#                <li class="menu__item js-menu-item menu--header--level-1__item">
#                 Travel
#                </li>
#                <li class="menu__item js-menu-item menu--header--level-1__item">
#                 Passes
#                </li>
#               </ul>
#              </li>
#              <li class="col-count--3 menu__item js-menu-item menu--inline__item menu--header__item menu-item--expanded menu-item--active-trail">
#               <a class="menu__link menu--header__link" data-drupal-link-system-path="&lt;front&gt;" data-listen="" data-toggle="" href="/autodesk-university/">
#                Discover
#                <div class="cio-ui-icon menu--header__link__icon" data-icon="icon-dropdown-arrow" data-type="">
#                </div>
#               </a>
#               <ul class="menu js-menu menu--inline menu--header--level-1 dropdown-animate" data-listen="" data-wat-link-section="Menu: mega-navigation">
#                <li class="menu__item js-menu-item menu--header--level-1__item menu-item--active-trail">
#                 Top Products
#                 <ul>
#                  <li class="menu__item js-menu-item menu--header--level-2__item menu-item--active-trail">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-query='{"facet_product":["urn:adsk.content:content:72007ddc-7682-45c6-aa81-63b1c458bd0c"]}' data-drupal-link-system-path="au-online" href="/autodesk-university/au-online?facet_product%5B0%5D=urn%3Aadsk.content%3Acontent%3A72007ddc-7682-45c6-aa81-63b1c458bd0c">
#                    AutoCAD
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-query='{"facet_product":["urn:adsk.content:content:6aa7f466-deae-4a54-accc-72bc50fb68cc"]}' data-drupal-link-system-path="au-online" href="/autodesk-university/au-online?facet_product%5B0%5D=urn%3Aadsk.content%3Acontent%3A6aa7f466-deae-4a54-accc-72bc50fb68cc" target="">
#                    BIM 360
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-query='{"facet_product":["urn:adsk.content:content:99f19be4-1261-4e84-a1b3-f2b339bdbafe"]}' data-drupal-link-system-path="au-online" href="/autodesk-university/au-online?facet_product%5B0%5D=urn%3Aadsk.content%3Acontent%3A99f19be4-1261-4e84-a1b3-f2b339bdbafe" target="">
#                    Revit
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-query='{"facet_product":["urn:adsk.content:content:4594dd66-7b8c-45dd-9bb2-1df1b909e871"]}' data-drupal-link-system-path="au-online" href="/autodesk-university/au-online?facet_product%5B0%5D=urn%3Aadsk.content%3Acontent%3A4594dd66-7b8c-45dd-9bb2-1df1b909e871" target="">
#                    Inventor
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-query='{"facet_product":["urn:adsk.content:content:0e1af96b-7177-4568-b328-58a2c7ff4ba9"]}' data-drupal-link-system-path="au-online" href="/autodesk-university/au-online?facet_product%5B0%5D=urn%3Aadsk.content%3Acontent%3A0e1af96b-7177-4568-b328-58a2c7ff4ba9" target="">
#                    3ds Max
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-query='{"facet_product":["urn:adsk.content:content:2909bf9f-2d27-429b-ad59-391775efb207"]}' data-drupal-link-system-path="au-online" href="/autodesk-university/au-online?facet_product%5B0%5D=urn%3Aadsk.content%3Acontent%3A2909bf9f-2d27-429b-ad59-391775efb207" target="">
#                    Fusion 360
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-query='{"facet_product":["urn:adsk.content:content:3324e2e0-c5c3-461d-b91a-f31517c7cb19"]}' data-drupal-link-system-path="au-online" href="/autodesk-university/au-online?facet_product%5B0%5D=urn%3Aadsk.content%3Acontent%3A3324e2e0-c5c3-461d-b91a-f31517c7cb19">
#                    Civil 3D
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-system-path="categories/products" href="/autodesk-university/categories/products" target="">
#                    View All
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#                <li class="menu__item js-menu-item menu--header--level-1__item">
#                 Top Topics
#                 <ul>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" href="https://www.autodesk.com/autodesk-university/Building-Information-Modeling">
#                    Building Information Modeling (BIM)
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-query='{"facet_activity":["urn:adsk.content:content:45d1c7f3-8eeb-4df9-82bd-5f4fb39054c1"]}' data-drupal-link-system-path="au-online" href="/autodesk-university/au-online?facet_activity%5B0%5D=urn%3Aadsk.content%3Acontent%3A45d1c7f3-8eeb-4df9-82bd-5f4fb39054c1" target="">
#                    CAD Management and IT
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" href="https://www.autodesk.com/autodesk-university/Generative-Design">
#                    Generative Design
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-query='{"facet_industry":["urn:adsk.content:content:576e0152-d4e4-4ba2-af6f-fda2c5146013"]}' data-drupal-link-system-path="au-online" href="/autodesk-university/au-online?facet_industry%5B0%5D=urn%3Aadsk.content%3Acontent%3A576e0152-d4e4-4ba2-af6f-fda2c5146013" target="">
#                    Product Design
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-query='{"facet_activity":["urn:adsk.content:content:0a6a8cc3-8f98-424d-95d6-ef206f92f357"]}' data-drupal-link-system-path="au-online" href="/autodesk-university/au-online?facet_activity%5B0%5D=urn%3Aadsk.content%3Acontent%3A0a6a8cc3-8f98-424d-95d6-ef206f92f357" target="">
#                    Product Lifecycle Management
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-query='{"facet_activity":["urn:adsk.content:content:b5b0ac77-b8a5-47b3-b78a-b871b71ffb2f"]}' data-drupal-link-system-path="au-online" href="/autodesk-university/au-online?facet_activity%5B0%5D=urn%3Aadsk.content%3Acontent%3Ab5b0ac77-b8a5-47b3-b78a-b871b71ffb2f" target="">
#                    Visualization
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-query='{"query":"\u0022Software Development\u0022"}' data-drupal-link-system-path="au-online" href="/autodesk-university/au-online?query=%22Software%20Development%22" target="">
#                    Forge &amp; Software Development
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" data-drupal-link-system-path="categories" href="/autodesk-university/categories" target="">
#                    View All
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#                <li class="menu__item js-menu-item menu--header--level-1__item">
#                 Other Learning Resources
#                 <ul>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" href="https://knowledge.autodesk.com/" target="">
#                    Autodesk Knowledge Network
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" href="https://enterprisehub.autodesk.com/">
#                    Autodesk Customer Success Hub
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" href="https://www.autodesk.com/events" target="">
#                    Autodesk Events
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" href="https://www.autodesk.com/training-and-certification/overview" target="">
#                    Autodesk Training Centers &amp; Certification
#                   </a>
#                  </li>
#                  <li class="menu__item js-menu-item menu--header--level-2__item">
#                   <a class="menu__link menu--header--level-2__link" href="https://servicesmarketplace.autodesk.com/" target="">
#                    Autodesk Services Marketplace
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </header>
#     <main role="main">
#      <a id="main-content" tabindex="-1">
#      </a>
#      <div class="region region-pre-content">
#       <div id="block-sitealertblock">
#       </div>
#      </div>
#      <div class="layout-content">
#       <div class="region region-content">
#        <div class="hidden" data-drupal-messages-fallback="">
#        </div>
#        <section class="library">
#         <div class="container container--dynamic">
#          <div class="grid">
#           <section class="library__results grid__item intermediate--three-fourths xlarge--three-fourths medium--one-whole small--one-whole">
#            <div class="library__header grid">
#             <div class="grid__item medium--four-tenths intermediate--five-tenths xlarge--six-tenths">
#              <h2 class="library__header-heading small--down--hide">
#               AU Library
#              </h2>
#             </div>
#             <div class="grid__item medium--six-tenths intermediate--five-tenths xlarge--four-tenths">
#              <div class="library__header-options">
#               <form accept-charset="UTF-8" action="/autodesk-university/au-online" class="auonline-search-filter" data-drupal-selector="auonline-search-filter" id="auonline-search-filter" method="post">
#                <div class="js-form-item form-item js-form-type-select form-item-query js-form-item-query" data-orient="column">
#                 <label class="label-above js-form-required form-required" for="edit-query">
#                  Sort by:
#                 </label>
#                 <select aria-required="true" class="form-select required" data-drupal-selector="edit-query" data-style="default" id="edit-query" name="query" required="required">
#                  <option selected="selected" value="relevance">
#                   Relevance
#                  </option>
#                  <option value="year_asc">
#                   Year: 2011 - Present
#                  </option>
#                  <option value="year_desc">
#                   Year: Present - 2011
#                  </option>
#                  <option value="title_asc">
#                   Alphabetical: A-Z
#                  </option>
#                  <option value="title_desc">
#                   Alphabetical: Z-A
#                  </option>
#                 </select>
#                </div>
#                <input autocomplete="off" data-drupal-selector="form-mmf1-6najq6g7jtwtulwmhzrdfhgbc1bs5lkeqr2yt4" name="form_build_id" type="hidden" value="form-mmf1-6najQ6g7jtwtulWMHZRdfhgbc1bs5lkeqR2yt4"/>
#                <input data-drupal-selector="edit-auonline-search-filter" name="form_id" type="hidden" value="auonline_search_filter"/>
#               </form>
#               <div class="library__header-filter">
#                <span class="library__header-filter-icon">
#                 <a href="javascript:;">
#                  <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                   <title>
#                    filter-24
#                   </title>
#                   <g id="assets">
#                    <path d="M13,20H11a1.08,1.08,0,0,1-1-1V14.75L3.69,9.86A2.13,2.13,0,0,1,3,8.5V7A1,1,0,0,1,4,6H20a1.12,1.12,0,0,1,.49.12A1,1,0,0,1,21,7V8.5a1.78,1.78,0,0,1-.71,1.39L14,14.75V19A1.08,1.08,0,0,1,13,20ZM4,7V8.5a1.24,1.24,0,0,0,.35.61L11,14.25V19h2V14.25l6.69-5.17A.79.79,0,0,0,20,8.5V7Z">
#                    </path>
#                   </g>
#                  </svg>
#                 </a>
#                </span>
#                <span class="library__header-filter-link">
#                 <a data-toggle="#library-filters" href="javascript:;">
#                  Filter (0)
#                 </a>
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="result grid">
#             <a class="result__image grid__item medium--one-third large--one-fourth text-decoration--none" href="/autodesk-university/class/Harnessing-high-resolution-scans-critical-infrastructure-repair-2022">
#              <div class="five-twelfths medium--one-whole">
#               <img alt="Autodesk University" height="163" src="https://www.autodesk.com/autodesk-university/themes/custom/forgecms_subtheme_auonline/assets/images/au-video-placeholder.jpg" width="288"/>
#              </div>
#              <div class="seven-twelfths medium--hide result__mobile-title">
#               Harnessing high-resolution scans for critical infrastructure repair
#              </div>
#              <div class="medium--hide one-whole">
#               <div class="au-details-list">
#                <span>
#                 Technical Instruction
#                </span>
#                <span>
#                 ·
#
#  New Orleans
#                </span>
#                <span>
#                 ·
#
#  2022
#                </span>
#                <span class="js-attended-status au-details-list__item" data-content-id="CES502532" style="display: none;">
#                 ·
#             Attended
#                </span>
#               </div>
#              </div>
#              <div class="result__attachments downloads-tab downloads-tab--teaser one-whole">
#              </div>
#             </a>
#             <div class="result__text grid__item medium--two-thirds large--three-fourths">
#              <a class="result__link" href="/autodesk-university/class/Harnessing-high-resolution-scans-critical-infrastructure-repair-2022">
#               <div class="medium--down--hide">
#                Harnessing high-resolution scans for critical infrastructure repair
#                <div class="au-details-list">
#                 <span>
#                  Technical Instruction
#                 </span>
#                 <span>
#                  ·
#
#  New Orleans
#                 </span>
#                 <span>
#                  ·
#
#  2022
#                 </span>
#                 <span class="js-attended-status au-details-list__item" data-content-id="CES502532" style="display: none;">
#                  ·
#             Attended
#                 </span>
#                </div>
#               </div>
#               <p class="result__body medium--down--hide">
#                <p>
#                 We will explore how reality capture was used to help construction and design teams repair an aging railway structure.  We will present best practices when...
#                </p>
#               </p>
#              </a>
#              <div class="dhclComponent speakers" data-anchorpoint="bottom-left" data-component="Speakers" data-contentid="urn:adsk.content:content:7af2c233-71eb-4461-8348-b64b4edc5ed4">
#              </div>
#             </div>
#             <div class="result__status au-sharing-widget">
#              <div class="js-tooltip-trigger dhclComponent bookmarktoggle" data-collectiontitle="My Bookmarks" data-component="BookmarkToggle" data-contentid="au_class-urn:adsk.content:content:7af2c233-71eb-4461-8348-b64b4edc5ed4" data-contentmetadata="" data-contentsource="au_class" data-contenttitle="Harnessing high-resolution scans for critical infrastructure repair" data-designation="aubookmarks" data-provider="aws" data-tooltip-placement="left" data-tooltip-template="dark" data-type="simple" role="button" title="Bookmark">
#              </div>
#              <div class="dhclComponent recommendation" data-component="Recommendation" data-contentid="urn:adsk.content:content:7af2c233-71eb-4461-8348-b64b4edc5ed4" data-type="simple-vertical">
#              </div>
#             </div>
#            </div>
#            <div class="result grid">
#             <a class="result__image grid__item medium--one-third large--one-fourth text-decoration--none" href="/autodesk-university/class/2D-Contour-Master-Class-2022">
#              <div class="five-twelfths medium--one-whole">
#               <img alt="Autodesk University" height="163" src="https://www.autodesk.com/autodesk-university/themes/custom/forgecms_subtheme_auonline/assets/images/au-video-placeholder.jpg" width="288"/>
#              </div>
#              <div class="seven-twelfths medium--hide result__mobile-title">
#               2D Contour Master Class
#              </div>
#              <div class="medium--hide one-whole">
#               <div class="au-details-list">
#                <span>
#                 Technical Instruction
#                </span>
#                <span>
#                 ·
#
#  New Orleans
#                </span>
#                <span>
#                 ·
#
#  2022
#                </span>
#                <span class="js-attended-status au-details-list__item" data-content-id="MFG502630" style="display: none;">
#                 ·
#             Attended
#                </span>
#               </div>
#              </div>
#              <div class="result__attachments downloads-tab downloads-tab--teaser one-whole">
#              </div>
#             </a>
#             <div class="result__text grid__item medium--two-thirds large--three-fourths">
#              <a class="result__link" href="/autodesk-university/class/2D-Contour-Master-Class-2022">
#               <div class="medium--down--hide">
#                2D Contour Master Class
#                <div class="au-details-list">
#                 <span>
#                  Technical Instruction
#                 </span>
#                 <span>
#                  ·
#
#  New Orleans
#                 </span>
#                 <span>
#                  ·
#
#  2022
#                 </span>
#                 <span class="js-attended-status au-details-list__item" data-content-id="MFG502630" style="display: none;">
#                  ·
#             Attended
#                 </span>
#                </div>
#               </div>
#               <p class="result__body medium--down--hide">
#                <p>
#                 With millions of uses per year, 2D contour is by far the most utilized toolpath in Fusion 360 manufacturing. From finishing a silhouette to tabbing a...
#                </p>
#               </p>
#              </a>
#              <div class="dhclComponent speakers" data-anchorpoint="bottom-left" data-component="Speakers" data-contentid="urn:adsk.content:content:30ac0bc8-6e24-4191-92c2-0db93e89af61">
#              </div>
#             </div>
#             <div class="result__status au-sharing-widget">
#              <div class="js-tooltip-trigger dhclComponent bookmarktoggle" data-collectiontitle="My Bookmarks" data-component="BookmarkToggle" data-contentid="au_class-urn:adsk.content:content:30ac0bc8-6e24-4191-92c2-0db93e89af61" data-contentmetadata="" data-contentsource="au_class" data-contenttitle="2D Contour Master Class" data-designation="aubookmarks" data-provider="aws" data-tooltip-placement="left" data-tooltip-template="dark" data-type="simple" role="button" title="Bookmark">
#              </div>
#              <div class="dhclComponent recommendation" data-component="Recommendation" data-contentid="urn:adsk.content:content:30ac0bc8-6e24-4191-92c2-0db93e89af61" data-type="simple-vertical">
#              </div>
#             </div>
#            </div>
#            <div class="result grid">
#             <a class="result__image grid__item medium--one-third large--one-fourth text-decoration--none" href="/autodesk-university/class/Top-Upchain-Secrets-2022">
#              <div class="five-twelfths medium--one-whole">
#               <img alt="Autodesk University" height="163" src="https://www.autodesk.com/autodesk-university/themes/custom/forgecms_subtheme_auonline/assets/images/au-video-placeholder.jpg" width="288"/>
#              </div>
#              <div class="seven-twelfths medium--hide result__mobile-title">
#               Top Upchain Secrets
#              </div>
#              <div class="medium--hide one-whole">
#               <div class="au-details-list">
#                <span>
#                 Technical Instruction
#                </span>
#                <span>
#                 ·
#
#  New Orleans
#                </span>
#                <span>
#                 ·
#
#  2022
#                </span>
#                <span class="js-attended-status au-details-list__item" data-content-id="MFG502704" style="display: none;">
#                 ·
#             Attended
#                </span>
#               </div>
#              </div>
#              <div class="result__attachments downloads-tab downloads-tab--teaser one-whole">
#              </div>
#             </a>
#             <div class="result__text grid__item medium--two-thirds large--three-fourths">
#              <a class="result__link" href="/autodesk-university/class/Top-Upchain-Secrets-2022">
#               <div class="medium--down--hide">
#                Top Upchain Secrets
#                <div class="au-details-list">
#                 <span>
#                  Technical Instruction
#                 </span>
#                 <span>
#                  ·
#
#  New Orleans
#                 </span>
#                 <span>
#                  ·
#
#  2022
#                 </span>
#                 <span class="js-attended-status au-details-list__item" data-content-id="MFG502704" style="display: none;">
#                  ·
#             Attended
#                 </span>
#                </div>
#               </div>
#               <p class="result__body medium--down--hide">
#                <p>
#                 This sessions is intended to illustrate a series of "pro tips" and best practices for efficient product development. We will be introducing and...
#                </p>
#               </p>
#              </a>
#              <div class="dhclComponent speakers" data-anchorpoint="bottom-left" data-component="Speakers" data-contentid="urn:adsk.content:content:b926e135-0edd-46c7-bc89-86d07b93450d">
#              </div>
#             </div>
#             <div class="result__status au-sharing-widget">
#              <div class="js-tooltip-trigger dhclComponent bookmarktoggle" data-collectiontitle="My Bookmarks" data-component="BookmarkToggle" data-contentid="au_class-urn:adsk.content:content:b926e135-0edd-46c7-bc89-86d07b93450d" data-contentmetadata="" data-contentsource="au_class" data-contenttitle="Top Upchain Secrets" data-designation="aubookmarks" data-provider="aws" data-tooltip-placement="left" data-tooltip-template="dark" data-type="simple" role="button" title="Bookmark">
#              </div>
#              <div class="dhclComponent recommendation" data-component="Recommendation" data-contentid="urn:adsk.content:content:b926e135-0edd-46c7-bc89-86d07b93450d" data-type="simple-vertical">
#              </div>
#             </div>
#            </div>
#            <div class="result grid">
#             <a class="result__image grid__item medium--one-third large--one-fourth text-decoration--none" href="/autodesk-university/class/Intelligent-Real-time-Collaborative-System-Opportunities-and-Challenges-2022">
#              <div class="five-twelfths medium--one-whole">
#               <img alt="Autodesk University" height="163" src="https://www.autodesk.com/autodesk-university/themes/custom/forgecms_subtheme_auonline/assets/images/au-video-placeholder.jpg" width="288"/>
#              </div>
# ...
#            </span>
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link au-link--iconed" href="https://www.youtube.com/user/AutodeskUniversity" target="_blank">
#            <span class="au-link__icon">
#             <svg viewbox="1190 450 100 100" xmlns="http://www.w3.org/2000/svg">
#              <g id="youtube" transform="translate(1190 450)">
#               <g data-name="Group 72" id="Group_72" transform="translate(-566)">
#                <path d="M609.1,60.3,627,50,609.1,39.7Z" data-name="Path 55" id="Path_55">
#                </path>
#               </g>
#               <g data-name="Group 73" id="Group_73" transform="translate(-566)">
#                <path d="M616,0a50,50,0,1,0,50,50A50.018,50.018,0,0,0,616,0Zm32.9,66.5a8.556,8.556,0,0,1-6.1,6.1C637.4,74,616,74,616,74s-21.4,0-26.8-1.4a8.556,8.556,0,0,1-6.1-6.1A82.963,82.963,0,0,1,581.7,50a101.139,101.139,0,0,1,1.4-16.5,8.556,8.556,0,0,1,6.1-6.1C594.6,26,616,26,616,26s21.4,0,26.8,1.5a8.774,8.774,0,0,1,6.1,6A82.963,82.963,0,0,1,650.3,50,91.148,91.148,0,0,1,648.9,66.5Z" data-name="Path 56" id="Path_56">
#                </path>
#               </g>
#              </g>
#             </svg>
#            </span>
#            <span class="au-link__text">
#             YouTube
#            </span>
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link au-link--iconed" href="/autodesk-university/blog" target="_blank">
#            <span class="au-link__icon">
#             <svg viewbox="2211 450 99.801 100.1" xmlns="http://www.w3.org/2000/svg">
#              <g id="blog" transform="translate(2210 450)">
#               <circle cx="14.2" cy="14.2" data-name="Ellipse 29" id="Ellipse_29" r="14.2" transform="translate(1 71.6)">
#               </circle>
#               <path d="M.1,53A35.78,35.78,0,0,1,47.2,71.5a34.711,34.711,0,0,1,2.9,14.2,34.467,34.467,0,0,1-3,14.2H62.3a49.847,49.847,0,0,0,2.1-14.2,50.018,50.018,0,0,0-50-50A49,49,0,0,0,.1,37.8V53Z" data-name="Path 68" id="Path_68" transform="translate(0.9)">
#               </path>
#               <path d="M.1,15.8A71.32,71.32,0,0,1,84.3,71.5a68.913,68.913,0,0,1,0,28.6H98.5a85.392,85.392,0,0,0,1.4-14.2A85.506,85.506,0,0,0,14.3,0,75.789,75.789,0,0,0,.1,1.3Z" data-name="Path 69" id="Path_69" transform="translate(0.9)">
#               </path>
#              </g>
#             </svg>
#            </span>
#            <span class="au-link__text">
#             Blog
#            </span>
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link au-link--iconed" href="http://www.xing.com" target="_blank">
#            <span class="au-link__icon">
#             <?xml version="1.0" encoding="utf-8"?>
#             <!-- Generator: Adobe Illustrator 19.2.0, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->
#             <svg id="Layer_1" style="enable-background:new 0 0 100 100;" version="1.1" viewbox="0 0 100 100" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#              <path d="M50,10c-22.1,0-40,17.9-40,40c0,22.1,17.9,40,40,40c22.1,0,40-17.9,40-40C90,27.9,72.1,10,50,10z M38.2,59.3h-6.6
# 	c-0.4,0-0.7-0.2-0.9-0.4c-0.2-0.3-0.2-0.6,0-1l7-12.3c0,0,0,0,0,0l-4.4-7.7c-0.2-0.4-0.2-0.8,0-1c0.2-0.3,0.5-0.5,0.9-0.5h6.6
# 	c1,0,1.5,0.7,1.8,1.3c0,0,4.5,7.9,4.5,7.9C46.8,46,40,58.1,40,58.1C39.7,58.7,39.2,59.3,38.2,59.3z M69.2,28.9L54.7,54.6
# 	c0,0,0,0,0,0l9.2,16.8c0.2,0.4,0.2,0.6,0,0.9c-0.2,0.3-0.5,0.1-0.9,0.1h-6.5c-1,0-1.5-0.4-1.9-1c0,0-9.3-16.7-9.3-16.8
# 	c0.5-0.8,14.5-25.9,14.5-25.9c0.4-0.6,1-1.3,1.7-1.3h0.3h6.5c0.4,0,0.7,0.2,0.9,0.5C69.4,28.1,69.4,28.6,69.2,28.9z">
#              </path>
#             </svg>
#            </span>
#            <span class="au-link__text">
#             Xing
#            </span>
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link au-link--iconed" href="mailto:au.info@autodeskuniversity.com" target="_blank">
#            <span class="au-link__icon">
#             <svg viewbox="2040 238 100 73.3" xmlns="http://www.w3.org/2000/svg">
#              <g id="email-solid" transform="translate(2040 225)">
#               <g data-name="Group 40" id="Group_40" transform="translate(0 13)">
#                <path d="M100,65.3v-54L73.3,38Zm-98.6,8H98.7L68.3,43l-19,19L31.1,43.7ZM0,12.7V65.3L26.3,39ZM0,0V3.2L49.3,52.5,100,2V0Z" data-name="Path 40" id="Path_40">
#                </path>
#               </g>
#              </g>
#             </svg>
#            </span>
#            <span class="au-link__text">
#             Email
#            </span>
#           </a>
#          </li>
#         </ul>
#        </nav>
#        <nav aria-labelledby="block-conferences-menu" class="grid__item medium--one-third large--two-twelfths au-menu-column" id="block-conferences" role="navigation">
#         <h2 class="au-menu-column__title" id="block-conferences-menu">
#          Conferences
#         </h2>
#         <ul class="menu" data-wat-link-section="Menu: conferences">
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/autodesk-university/advisory-council">
#            AU Advisory Council
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/autodesk-university/au-community-rules">
#            AU Community Rules
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/autodesk-university/blog">
#            AU Blog
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="/autodesk-university/contact-us">
#            Contact us
#           </a>
#          </li>
#         </ul>
#        </nav>
#        <nav aria-labelledby="block-learnonline-menu" class="grid__item medium--one-third large--two-twelfths au-menu-column" id="block-learnonline" role="navigation">
#         <h2 class="au-menu-column__title" id="block-learnonline-menu">
#          Learn Online
#         </h2>
#         <ul class="menu" data-wat-link-section="Menu: learn-online">
#          <li class="menu__item menu-item--active-trail">
#           <a class="menu__link au-link" href="/autodesk-university/au-online?query=general%20session" target="_blank">
#            Keynotes
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/autodesk-university/conference/schedule?__scheduleFilter=%7B%22locale%22%3A%22en_US%22%2C%22term%22%3A%22AutoCAD%22%7D">
#            AutoCAD sessions
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/autodesk-university/conference/schedule?__scheduleFilter=%7B%22locale%22%3A%22en_US%22%2C%22term%22%3A%22BIM%20360%22%7D">
#            BIM 360 sessions
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/autodesk-university/conference/schedule?__scheduleFilter=%7B%22product%22%3A%22urn%3Aadsk.content%3Acontent%3A2be8b185-1e39-49a7-98b7-ed741c46af6e%22%2C%22locale%22%3A%22en_US%22%7D">
#            Dynamo sessions
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/autodesk-university/conference/schedule?__scheduleFilter=%7B%22product%22%3A%22urn%3Aadsk.content%3Acontent%3A55fac809-a433-408e-b809-634058be0c7c%22%2C%22locale%22%3A%22en_US%22%7D">
#            Forge sessions
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/autodesk-university/conference/schedule?__scheduleFilter=%7B%22product%22%3A%22urn%3Aadsk.content%3Acontent%3A2909bf9f-2d27-429b-ad59-391775efb207%22%2C%22locale%22%3A%22en_US%22%7D">
#            Fusion 360 sessions
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/autodesk-university/conference/schedule?__scheduleFilter=%7B%22product%22%3A%22urn%3Aadsk.content%3Acontent%3A99f19be4-1261-4e84-a1b3-f2b339bdbafe%22%2C%22locale%22%3A%22en_US%22%7D">
#            Revit sessions
#           </a>
#          </li>
#         </ul>
#        </nav>
#        <nav aria-labelledby="block-autodesk-menu" class="grid__item medium--one-third large--two-twelfths au-menu-column" id="block-autodesk" role="navigation">
#         <h2 class="au-menu-column__title" id="block-autodesk-menu">
#          Autodesk
#         </h2>
#         <ul class="menu" data-wat-link-section="Menu: autodesk">
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/company" target="_blank">
#            About
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/careers" target="_blank">
#            Careers
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/store-footer-help-download?mktvar004=ilt_wwm_amer_us_nc__Footer_ShoppingWithUs_DLSoftware#download-info" target="_blank">
#            Free product trials
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://www.autodesk.com/buy-online" target="_blank">
#            Buy products online
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="https://knowledge.autodesk.com" target="_blank">
#            Support &amp; learning
#           </a>
#          </li>
#          <li class="menu__item">
#           <a class="menu__link au-link" href="http://news.autodesk.com/" target="_blank">
#            Newsroom
#           </a>
#          </li>
#         </ul>
#        </nav>
#       </div>
#       <div class="region region-footer-copyright region--copyright">
#        <div class="region-copyright-inner">
#         <div class="block block-block-content block-block-content32136e57-3c9d-4685-9a19-7ecdc58d7e3d" id="block-copyright">
#          <p>
#           © Copyright 2022 Autodesk, Inc. All rights reserved.
#           <a href="https://www.autodesk.com/company/legal-notices-trademarks">
#            Legal Notices &amp; Trademarks
#           </a>
#           |
#           <a href="https://www.autodesk.com/company/legal-notices-trademarks/privacy-statement">
#            Privacy
#           </a>
#          </p>
#         </div>
#        </div>
#        <a class="footer-logo" href="/autodesk-university/">
#         <img alt="Site Logo" src="https://damassets.autodesk.net/content/dam/autodesk/logos/autodesk-logo-blk.svg"/>
#        </a>
#       </div>
#      </div>
#     </footer>
#    </div>
#    <script type="text/javascript">
#     window._privacyUserLanguage = "en";
#    </script>
#    <script type="text/javascript">
#     (function(a,b,c,d){
#     a='https://tags.tiqcdn.com/utag/autodesk/forge-cms/prod/utag.js';
#     b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;
#     a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
#     })();
#    </script>
#   </div>
#   <script data-drupal-selector="drupal-settings-json" type="application/json">
#    {"path":{"baseUrl":"\/autodesk-university\/","scriptPath":null,"pathPrefix":"","currentPath":"au-online","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"ajaxPageState":{"libraries":"addtoany\/addtoany,auonline_alert\/close_alert,auonline_bookmark\/toggle_bookmark,auonline_common\/class-attended-status,auonline_community\/auonline-community,auonline_library\/facet_click,auonline_profile\/role-access-js,chosen\/drupal.chosen,chosen_lib\/chosen.css,codesnippet\/codesnippet.highlightjs,codesnippet\/codesnippet.style.github,core\/html5shiv,core\/modernizr,forgecms_analytics\/retain_marketing_parameters,forgecms_base\/global-css,forgecms_base\/global-js,forgecms_base\/icons-all,forgecms_base\/icons-owf,forgecms_base\/js-custom-blog-sidebar,forgecms_base\/js-custom-copy-to-clipboard,forgecms_base\/js-custom-faq,forgecms_base\/js-custom-forms,forgecms_base\/js-custom-menu-admin,forgecms_base\/js-custom-menu-main,forgecms_base\/js-custom-more-toggle,forgecms_base\/js-custom-node-load,forgecms_base\/js-custom-spinner,forgecms_base\/js-lib-chosen,forgecms_base\/js-lib-tab,forgecms_subtheme_auonline\/au-closed-captioning,forgecms_subtheme_auonline\/au-modal-js,forgecms_subtheme_auonline\/css-global,forgecms_subtheme_auonline\/js-custom-menu-main,forgecms_subtheme_auonline\/js-dynatrace-live,forgecms_subtheme_auonline\/js-global-libraries,forgecms_subtheme_auonline\/js-scripts,lazy\/lazy,system\/base","theme":"forgecms_subtheme_auonline","theme_token":null},"ajaxTrustedUrl":{"form_action_p_pvdeGsVG5zNF_XLGPTvYSKCf43t8qZYSwcfZl2uzM":true,"\/autodesk-university\/au-online":true},"forgeCmsAnalyticsRetainMarketingParameters":{"status":1,"parameters":["stateToken","utm_stateToken","__stateToken","utm_campaign","utm_id","utm_medium","utm_source","__leadid","__mkt_tok","__mktvar002","__pass","__refid","__vycustom_id","__vyemail","utm_leadid","utm_mkt_tok","utm_mktvar002","utm_pass","utm_refid","utm_vycustom_id","utm_vyemail","urlParamToken","__urlParamToken","mktvar002"],"exclude":["\/admin",".cloudfront.net\/",""]},"lazy":{"lazysizes":{"lazyClass":"lazyload","loadedClass":"lazyloaded","loadingClass":"lazyloading","preloadClass":"lazypreload","errorClass":"lazyerror","autosizesClass":"lazyautosizes","srcAttr":"data-src","srcsetAttr":"data-srcset","sizesAttr":"data-sizes","minSize":40,"customMedia":[],"init":true,"expFactor":1.5,"hFac":0.8,"loadMode":2,"loadHidden":true,"ricTimeout":0,"throttleDelay":125,"plugins":[]},"placeholderSrc":"","preferNative":true},"forge_more_toggle":{"toggle_more":"Show More","toggle_less":"Show Less"},"chosen":{"selector":"select:visible,select.form-select","minimum_single":0,"minimum_multiple":0,"minimum_width":200,"use_relative_width":false,"options":{"disable_search":false,"disable_search_threshold":8,"allow_single_deselect":false,"search_contains":false,"placeholder_text_multiple":"Choose some options","placeholder_text_single":"Choose an option","no_results_text":"No results match","max_shown_results":null,"inherit_select_classes":true}},"auonline_community":{"data-src":"https:\/\/www.autodesk.com\/autodesk-university\/cl\/static\/js\/dh-community-library.js","data-env":"production","data-libraryid":"urn:adsk.content:library:78756fcf-e6f3-4184-abdd-04afc0337a02","data-signin":"\/autodesk-university\/login?destination=\/au-online","data-signout":"\/autodesk-university\/logout","data-config":"{\u0022au2020\u0022: { \u0022loadProfiles\u0022: false, \u0022schedulePageSize\u0022: 4 }, \u0022userAccess\u0022: { \u0022disableBookmarking\u0022: false } }","data-uploadlock":0,"data-collectionslock":0,"data-communitylock":1},"user":{"uid":0,"permissionsHash":"1a85ac696ffacba0d19e6f320d94bd2e11891f7b0aef0f56ade64120b1ed175b"}}
#   </script>
#   <script src="/autodesk-university/sites/default/files/js/js_JI9DYI2JD-dGzgXqw-BdPTaTTael_7QWz7wj6x_YFLE.js">
#   </script>
#   <script async="" src="//static.addtoany.com/menu/page.js">
#   </script>
#   <script src="/autodesk-university/sites/default/files/js/js_L2d8UxRMSf7QqJDVernWlHI3LRR41fUqmZm0mcs2RiU.js">
#   </script>
#   <script crossorigin="anonymous" src="//prod-rum.apm.autodesk.com/au_prod.js">
#   </script>
#   <script src="/autodesk-university/sites/default/files/js/js_h28L_KCCuBBpAPgD8a0iRAJIe7uTtNXu9CzJ1fA5jyI.js">
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"NRJS-69ddd2f3aaa8db54fa2","applicationID":"641597882","transactionName":"Y1ZUZBACWhVWBhJbXFocd1MWClsIGCEUR0NVX2pRFwxaCl4LA21fXVFEURAaaCVYCxJAXFhfU0I+L10ERQQUS3BbXUJCDQ9YA0VIWFFcWkdTXhY=","queueTime":0,"applicationTime":1655,"atts":"TxFXElgYSRs=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#  </body>
# </html>
